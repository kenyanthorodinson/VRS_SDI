# %%
print("Good afternoon Mr. Kirera?")
# Out:
# Good afternoon Mr. Kirera?

# %%
# Load geospatial libraries
import osmnx
import geopandas as gpd

# Load matplotlib plotting functionality inline
# %matplotlib inline

# Select area of interest
# aoi = "Nairobi, Kenya"
aoi = "Kamppi, Helsinki, Finland"

# Initialize routes graph
graph = osmnx.graph_from_place(aoi, network_type="drive") # 'walk', 'bike','drive','drive_service','all','all_private'

figure, ax = osmnx.plot_graph(graph)
